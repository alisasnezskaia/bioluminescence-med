# %% [markdown]
# # 02 Feature Engineering\n\n*Add your notes here as you work through the data.*

# %%
import sys\nsys.path.append('..')\n\nimport numpy as np\nimport pandas as pd\nimport xarray as xr\nimport matplotlib.pyplot as plt
